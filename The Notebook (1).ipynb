# %% [markdown]
# # WELCOME TO THE NOTEBOOK
# ---
#
# In this project, I am going to demonstrate about two important data analysis methods **EDA** (Exploratory Data Analysis) and **CDA** (Confirmatory Data Analysis).

# %% [markdown]
# ### Task 1: What Is Exploratory Data Analysis (EDA)?
#
# Exploratory Data Analysis (EDA) is an approach to analyzing data. It's where the researcher takes a bird's eye view of the data and tries to make some sense of it. It's often the first step in data analysis, implemented before any formal statistical techniques are applied.

# %% [markdown]
# Importing Modules

# %%
# Pandas Module
import pandas as pd

import datetime

# Data Visualization Module
import plotly.express as px
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Let's load our canons

# %%
data = pd.read_csv('dataset.csv', header= 0,
                        encoding= 'unicode_escape')
data.head()
# Out:
#    Order Date    Customer Name       State         Category Sub-Category  \
# 0   11/8/2016      Claire Gute    Kentucky        Furniture    Bookcases
# 1   11/8/2016      Claire Gute    Kentucky        Furniture       Chairs
# 2   6/12/2016  Darrin Van Huff  California  Office Supplies       Labels
# 3  10/11/2015   Sean O'Donnell     Florida        Furniture       Tables
# 4  10/11/2015   Sean O'Donnell     Florida  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %% [markdown]
# # Checking the data size

# %%
data.shape
# Out:
# (9994, 9)

# %% [markdown]
# # Checking the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   State          9994 non-null   object
#  3   Category       9994 non-null   object
#  4   Sub-Category   9994 non-null   object
#  5   Product Name   9994 non-null   object
#  6   Sales          9994 non-null   float64
#  7   Quantity       9994 non-null   int64
#  8   Profit         9994 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 702.8+ KB

# %% [markdown]
# # #2: EDA
#
# Understanding the big picture
# 	This involves various methods to understand the dataset(without going into deatails)
# 	"We try to understand the problem we want to solve, thinking about the entire dataset and the meaning of the variables."
#
# - Variable: name of the variable
# - Type: this type or format of the variable. This can be categorical, numerical, boolean and so on.
# - Context: useful information to understand the semantic space of the variable.
# - `Expectations`(most important): how relevant is this variable with respect to our task ? We can use a scale of 10.
# - Comments: whether or not we have any comments to make on the variable.

# %% [markdown]
# # In our data, we have the following information:
#
#     Time Information (Order Data)
#     Customer Information (Customer Name)
#     Place Information (State name)
#     Hierarchical Information about the products (Category, Sub-category, Product Name)
#     Sale Information (sales, profit, quantity)
#
#
# now let's start our exploration

# %% [markdown]
# # #3: Data Exploration: Time Information

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   datetime64[ns]
#  1   Customer Name  9994 non-null   object
#  2   State          9994 non-null   object
#  3   Category       9994 non-null   object
#  4   Sub-Category   9994 non-null   object
#  5   Product Name   9994 non-null   object
#  6   Sales          9994 non-null   float64
#  7   Quantity       9994 non-null   int64
#  8   Profit         9994 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 702.8+ KB

# %%
from_ = data["Order Date"].min()
to_ = data["Order Date"].max()

# %% [markdown]
# # What is the timespan of our data?

# %%
print("We have the sales information from", from_ , "to", to_)
# Out:
# We have the sales information from 2014-01-03 00:00:00 to 2017-12-30 00:00:00

# %% [markdown]
# # Now let's sort our data by the date

# %%
data
# Out:
#      Order Date     Customer Name       State         Category Sub-Category  \
# 0    2016-11-08       Claire Gute    Kentucky        Furniture    Bookcases
# 1    2016-11-08       Claire Gute    Kentucky        Furniture       Chairs
# 2    2016-06-12   Darrin Van Huff  California  Office Supplies       Labels
# 3    2015-10-11    Sean O'Donnell     Florida        Furniture       Tables
# 4    2015-10-11    Sean O'Donnell     Florida  Office Supplies      Storage
# ...         ...               ...         ...              ...          ...
# 9989 2014-01-21  Tom Boeckenhauer     Florida        Furniture  Furnishings
# 9990 2017-02-26       Dave Brooks  California        Furniture  Furnishings
# 9991 2017-02-26       Dave Brooks  California       Technology       Phones
# 9992 2017-02-26       Dave Brooks  California  Office Supplies        Paper
# 9993 2017-05-04      Chris Cortes  California  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#         Profit
# 0      41.9136
# 1     219.5820
# 2       6.8714
# 3    -383.0310
# 4       2.5164
# ...        ...
# 9989    4.1028
# 9990   15.6332
# 9991   19.3932
# 9992   13.3200
# 9993   72.9480
#
# [9994 rows x 9 columns]

# %%
pd.to_datetime(data["Order Date"])
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9989   2014-01-21
# 9990   2017-02-26
# 9991   2017-02-26
# 9992   2017-02-26
# 9993   2017-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %% [markdown]
# **`important method`**
#
#     pd.to_datetime()
#
# Converts argument to datetime.

# %%
data = data.sort_values("Order Date")
data.head()
# Out:
#      Order Date  Customer Name         State         Category Sub-Category  \
# 7980 2014-01-03  Darren Powers         Texas  Office Supplies        Paper
# 739  2014-01-04  Phillina Ober      Illinois  Office Supplies       Labels
# 740  2014-01-04  Phillina Ober      Illinois  Office Supplies      Storage
# 741  2014-01-04  Phillina Ober      Illinois  Office Supplies      Binders
# 1759 2014-01-05     Mick Brown  Pennsylvania  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 739                                           Avery 508   11.784         3
# 740                       SAFCO Boltless Steel Shelving  272.736         3
# 741          GBC Standard Plastic Binding Systems Combs    3.540         2
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#        Profit
# 7980   5.5512
# 739    4.2717
# 740  -64.7748
# 741   -5.4870
# 1759   4.8840

# %% [markdown]
# # Some data preparation: let's extract year, month, and day from the Order Date column

# %%
data["Year"] = pd.DatetimeIndex(data["Order Date"]).year

# %%
data["Month"] = pd.DatetimeIndex(data["Order Date"]).month

# %%
data["Day"] = pd.DatetimeIndex(data["Order Date"]).day

# %% [markdown]
# Profit gained over time by different product categories

# %%
# i have sliced and combined year and category columns using groupby and used aggregate method to add up profit using sum operation.
profit_data = data.groupby(["Year","Category"]).agg({"Profit":sum}).reset_index()

# %%
profit_data
# Out:
#     Year         Category      Profit
# 0   2014        Furniture   5457.7255
# 1   2014  Office Supplies  22593.4161
# 2   2014       Technology  21492.8325
# 3   2015        Furniture   3015.2029
# 4   2015  Office Supplies  25099.5338
# 5   2015       Technology  33503.8670
# 6   2016        Furniture   6959.9531
# 7   2016  Office Supplies  35061.2292
# 8   2016       Technology  39773.9920
# 9   2017        Furniture   3018.3913
# 10  2017  Office Supplies  39736.6217
# 11  2017       Technology  50684.2566

# %% [markdown]
# # Visualizing the results using a line chart

# %%
px.line(profit_data, x = "Year", y = "Profit", color = "Category")
# Out:
# <div>                            <div id="509d98b5-9da9-46af-9fab-9b78d4d0e980" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("509d98b5-9da9-46af-9fab-9b78d4d0e980")) {                    Plotly.newPlot(                        "509d98b5-9da9-46af-9fab-9b78d4d0e980",                        [{"hovertemplate":"Category=Furniture<br>Year=%{x}<br>Profit=%{y}<extra></extra>","legendgroup":"Furniture","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Furniture","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[5457.7255000000005,3015.2028999999998,6959.9531,3018.3913000000002],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Office Supplies<br>Year=%{x}<br>Profit=%{y}<extra></extra>","legendgroup":"Office Supplies","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Office Supplies","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[22593.4161,25099.5338,35061.2292,39736.6217],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Technology<br>Year=%{x}<br>Profit=%{y}<extra></extra>","legendgroup":"Technology","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Technology","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[21492.8325,33503.867,39773.992,50684.2566],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b ...

# %% [markdown]
# # #4 Data Exploration: Customer Aspect

# %% [markdown]
# # let's see how many unique costumers do we have

# %%
len(data["Customer Name"].unique())
# Out:
# 793

# %% [markdown]
# # let's see the yearly change in number of unique customers

# %%
customer_data = data.groupby("Year").agg({"Customer Name":"nunique"}).reset_index()
customer_data
# Out:
#    Year  Customer Name
# 0  2014            595
# 1  2015            573
# 2  2016            638
# 3  2017            693

# %% [markdown]
# # visualizing the result

# %%
px.bar(customer_data, x = "Year", y = "Customer Name")
# Out:
# <div>                            <div id="f5dffb4d-bfcd-43bf-8ef0-e1e518e77909" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5dffb4d-bfcd-43bf-8ef0-e1e518e77909")) {                    Plotly.newPlot(                        "f5dffb4d-bfcd-43bf-8ef0-e1e518e77909",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Customer Name=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[595,573,638,693],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outline ...

# %% [markdown]
# # Top 10 customers who brought the highest profit

# %%
top10_profit = data.groupby("Customer Name").agg({"Profit" : "sum"}).reset_index().sort_values("Profit", ascending = False).head(10)

# %%
top10_profit["Customer Name"].duplicated()
# Out:
# 730    False
# 622    False
# 671    False
# 334    False
# 6      False
# 757    False
# 157    False
# 431    False
# 35     False
# 194    False
# Name: Customer Name, dtype: bool

# %%
#28.656896
px.bar(top10_profit, x = "Customer Name", y = "Profit")
# Out:
# <div>                            <div id="0170811e-f303-4395-bade-e66365854c87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0170811e-f303-4395-bade-e66365854c87")) {                    Plotly.newPlot(                        "0170811e-f303-4395-bade-e66365854c87",                        [{"alignmentgroup":"True","hovertemplate":"Customer Name=%{x}<br>Profit=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tamara Chand","Raymond Buch","Sanjit Chand","Hunter Lopez","Adrian Barton","Tom Ashbrook","Christopher Martinez","Keith Dawkins","Andy Reiter","Daniel Raglin"],"xaxis":"x","y":[8981.323900000001,6976.0959,5757.411899999999,5622.4292,5444.8054999999995,4703.7883,3899.8903999999998,3038.6254,2884.6208,2869.076],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"col ...

# %% [markdown]
# # #5 Data Exploration: Place (location) Aspect

# %% [markdown]
# Let's analyze the profits gained in different states in the US

# %%
geo_data = data.groupby("State").agg({"Profit":"sum"}).reset_index()
geo_data
# Out:
#                    State      Profit
# 0                Alabama   5786.8253
# 1                Arizona  -3427.9246
# 2               Arkansas   4008.6871
# 3             California  76381.3871
# 4               Colorado  -6527.8579
# 5            Connecticut   3511.4918
# 6               Delaware   9977.3748
# 7   District of Columbia   1059.5893
# 8                Florida  -3399.3017
# 9                Georgia  16250.0433
# 10                 Idaho    826.7231
# 11              Illinois -12607.8870
# 12               Indiana  18382.9363
# 13                  Iowa   1183.8119
# 14                Kansas    836.4435
# 15              Kentucky  11199.6966
# 16             Louisiana   2196.1023
# 17                 Maine    454.4862
# 18              Maryland   7031.1788
# 19         Massachusetts   6785.5016
# 20              Michigan  24463.1876
# 21             Minnesota  10823.1874
# 22           Mississippi   3172.9762
# 23              Missouri   6436.2105
# 24               Montana   1833.3285
# 25              Nebraska   2037.0942
# 26                Nevada   3316.7659
# 27         New Hampshire   1706.5028
# 28            New Jersey   9772.9138
# 29            New Mexico   1157.1161
# 30              New York  74038.5486
# 31        North Carolina  -7490.9122
# 32          North Dakota    230.1497
# 33                  Ohio -16971.3766
# 34              Oklahoma   4853.9560
# 35                Oregon  -1190.4705
# 36          Pennsylvania -15559.9603
# 37          Rhode Island   7285.6293
# 38        South Carolina   1769.0566
# 39          South Dakota    394.8283
# 40             Tennessee  -5341.6936
# 41                 Texas -25729.3563
# 42                  Utah   2546.5335
# 43               Vermont   2244.9783
# 44              Virginia  18597.9504
# 45            Washington  33402.6517
# 46         West Virginia    185.9216
# 47             Wisconsin   8401.8004
# 48               Wyoming    100.1960

# %% [markdown]
# ### Let's create a choropleth map
# Plotly uses abbreviated two-letter postal codes for state locations so it will be necessary to create a dictionary that contains conversions of the full names of states into abbreviations.

# %%
state_codes = {
        'Alabama': 'AL',
        'Alaska': 'AK',
        'Arizona': 'AZ',
        'Arkansas': 'AR',
        'California': 'CA',
        'Colorado': 'CO',
        'Connecticut': 'CT',
        'Delaware': 'DE',
        'District of Columbia': 'DC',
        'Florida': 'FL',
        'Georgia': 'GA',
        'Hawaii': 'HI',
        'Idaho': 'ID',
        'Illinois': 'IL',
        'Indiana': 'IN',
        'Iowa': 'IA',
        'Kansas': 'KS',
        'Kentucky': 'KY',
        'Louisiana': 'LA',
        'Maine': 'ME',
        'Maryland': 'MD',
        'Massachusetts': 'MA',
        'Michigan': 'MI',
        'Minnesota': 'MN',
        'Mississippi': 'MS',
        'Missouri': 'MO',
        'Montana': 'MT',
        'Nebraska': 'NE',
        'Nevada': 'NV',
        'New Hampshire': 'NH',
        'New Jersey': 'NJ',
        'New Mexico': 'NM',
        'New York': 'NY',
        'North Carolina': 'NC',
        'North Dakota': 'ND',
        'Ohio': 'OH',
        'Oklahoma': 'OK',
        'Oregon': 'OR',
        'Pennsylvania': 'PA',
        'Rhode Island': 'RI',
        'South Carolina': 'SC',
        'South Dakota': 'SD',
        'Tennessee': 'TN',
        'Texas': 'TX',
        'Utah': 'UT',
        'Vermont': 'VT',
        'Virginia': 'VA',
        'Washington': 'WA',
        'West Virginia': 'WV',
        'Wisconsin': 'WI',
        'Wyoming': 'WY'
}

# %% [markdown]
# # let's map the abbreviated two-letter postal codes to the State column

# %%
geo_data.State = geo_data.State.map(state_codes)

# %%
px.choropleth(geo_data,
              locations = "State",
              color = "Profit",
              locationmode = "USA-states",
              scope = "usa",
              title = "Profit gained in each state"
              
)
# Out:
# <div>                            <div id="314a29c0-4efd-4c97-86f1-84809ff9553c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("314a29c0-4efd-4c97-86f1-84809ff9553c")) {                    Plotly.newPlot(                        "314a29c0-4efd-4c97-86f1-84809ff9553c",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State=%{location}<br>Profit=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AZ","AR","CA","CO","CT","DE","DC","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[5786.8253,-3427.9246,4008.6871,76381.3871,-6527.8579,3511.4918,9977.3748,1059.5893,-3399.3017,16250.043300000001,826.7231,-12607.887,18382.9363,1183.8119,836.4435,11199.6966,2196.1023,454.4862,7031.1788,6785.5016,24463.1876,10823.187399999999,3172.9762,6436.2105,1833.3285,2037.0942,3316.7659000000003,1706.5028,9772.9138,1157.1161,74038.5486,-7490.912200000001,230.1497,-16971.3766,4853.956,-1190.4705,-15559.9603,7285.6293,1769.0566,394.8283,-5341.6936,-25729.3563,2546.5335,2244.9782999999998,18597.9504,33402.6517,185.9216,8401.8004,100.196],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth" ...

# %%
ex_data = data[data.Category == "Technology"].groupby("State").agg({"Profit" : "sum"}).reset_index()

px.choropleth(ex_data,
             locations = ex_data.State.map(state_codes),
             color = "Profit",
             locationmode = "USA-states",
             scope = "usa",
             title = "Profit Gained In different states",
             color_continuous_scale = "Pubu")
# Out:
# <div>                            <div id="0de5e066-d105-4f48-a910-8e1ac782e486" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0de5e066-d105-4f48-a910-8e1ac782e486")) {                    Plotly.newPlot(                        "0de5e066-d105-4f48-a910-8e1ac782e486",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"locations=%{location}<br>Profit=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AZ","AR","CA","CO","CT","DE","DC","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WI"],"name":"","z":[3297.8029,112.50119999999997,1261.4384,29470.0368,-3471.5845,780.9336,6239.0508,648.5624,530.8047999999999,4399.6597,92.09729999999999,4822.5592,11000.8773,318.3682,174.9866,4156.636399999999,1015.0152,251.0328,1322.8776,1755.7501,4782.3025,1018.8008,986.4024,3014.7267999999995,1523.0354000000002,961.5150000000001,512.8456,902.7073,4170.198,337.2828,42186.7856,-3583.304,-12649.9401,1580.9003,126.35640000000001,-3191.2216000000003,4598.012299999999,453.5875,133.8966,66.03370000000004,3291.429,581.7351,447.2863,7407.7544,15019.3435,2597.0697],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# # #6 Data Exploration - Hierarchical Information about the products

# %%
product_data = data.groupby(["Category", "Sub-Category"]).agg({"Profit":"sum"}).reset_index()
product_data = product_data[product_data.Profit > 0]
product_data["Sales"] = "Any"
product_data
# Out:
#            Category Sub-Category      Profit Sales
# 1         Furniture       Chairs  26590.1663   Any
# 2         Furniture  Furnishings  13059.1436   Any
# 4   Office Supplies   Appliances  18138.0054   Any
# 5   Office Supplies          Art   6527.7870   Any
# 6   Office Supplies      Binders  30221.7633   Any
# 7   Office Supplies    Envelopes   6964.1767   Any
# 8   Office Supplies    Fasteners    949.5182   Any
# 9   Office Supplies       Labels   5546.2540   Any
# 10  Office Supplies        Paper  34053.5693   Any
# 11  Office Supplies      Storage  21278.8264   Any
# 13       Technology  Accessories  41936.6357   Any
# 14       Technology      Copiers  55617.8249   Any
# 15       Technology     Machines   3384.7569   Any
# 16       Technology       Phones  44515.7306   Any

# %%
px.sunburst(product_data, path = ["Sales", "Category", "Sub-Category"], values = "Profit")
# Out:
# <div>                            <div id="212203cd-d2b5-4d23-8c7e-4adf08cba670" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface": ...

# %% [markdown]
# # #7 Data Exploration: Product Sales information (Sales, Quantity, Profit)

# %% [markdown]
# Distribution Analysis on **Quantity** column

# %% [markdown]
# Let's check the statistical summary of the column

# %%
data.Quantity.describe()
# Out:
# count    9994.000000
# mean        3.789574
# std         2.225110
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %%
px.histogram(data, x = "Quantity")
# Out:
# <div>                            <div id="108a86fd-9999-4444-8666-caf6c7e09a10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("108a86fd-9999-4444-8666-caf6c7e09a10")) {                    Plotly.newPlot(                        "108a86fd-9999-4444-8666-caf6c7e09a10",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Quantity=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2,3,3,2,3,2,9,2,3,2,4,4,1,3,3,7,2,3,1,1,2,6,3,5,2,5,7,2,6,3,3,6,4,5,3,6,3,2,4,10,4,5,5,3,5,2,1,3,4,3,2,3,5,3,1,3,7,2,4,7,3,3,6,2,2,2,3,13,3,8,3,2,1,4,3,1,2,2,2,6,2,5,5,3,2,3,4,2,5,1,4,2,7,4,2,2,1,3,2,3,2,3,6,3,2,2,2,3,3,5,3,2,14,2,5,3,4,2,5,3,3,3,4,3,4,6,2,6,5,3,3,3,3,3,6,5,2,3,1,4,5,3,3,1,3,3,8,5,3,5,2,3,3,2,6,2,6,5,5,1,2,3,3,4,3,2,3,3,5,6,2,3,14,3,4,2,6,4,1,12,2,2,1,2,2,4,1,3,3,3,2,3,2,2,6,3,7,6,10,6,4,2,4,3,7,7,4,3,1,2,4,3,6,7,4,3,2,2,3,10,4,2,3,3,4,3,5,3,3,3,3,4,3,5,7,3,2,1,5,3,5,3,4,2,3,6,2,2,5,7,2,2,4,6,5,3,2,4,2,4,3,1,3,3,7,2,7,3,3,5,5,5,2,5,2,7,1,2,1,2,7,2,4,2,2,4,2,3,5,7,5,7,2,2,3,3,4,1,2,2,6,5,2,4,7,7,2,5,1,1,3,6,5,2,7,4,2,2,3,3,3,3,6,2,2,1,3,1,7,2,3,9,5,3,2,1,8,3,4,1,8,2,7,2,6,6,7,3,3,1,4,7,2,3,5,14,3,4,12,10,13,2,4,6,2,3,3,3,4,4,5,2,3,3,11,5,2,4,5,6,5,8,3,1,3,2,2,8,4,2,3,5,3,3,5,5,6,2,3,3,2,2,2,5,9,2,1,3,5,2,2,3,2,2,3,5,5,3,2,7,3,3,2,2,6,4,7,4,2,1,2,3,2,2,3,2,8,6,2,3,3,4,5,3,5,3,4,7,3,5,3,6,5,1,5,2,7,8,2,3,9,1,4,3,2,3,7,2,2,2,3,8,6,2,3,5,3,1,4,3,2,5,9,7,9,4,2,5,2,3,3,8,7,7,3,3,1,6,2,6,1,2,2,9,5,2,2,1,2,3,2,2,2,3,2,2,2,2,2,3,5,4,12,1,6,10,4,6,4,4,3,3,5,3,3,2,4,3,3,2,6,6,5,4,7,4,5,6,7,3,6,3,2,3,2,7,3,6,4,2,2,2,4,2,2,2,1,3,3,2,10,2,2,9,3,3,3,6,3,2,7,6,5,9,4,2,2,1,2,3,7,2,2,4,7,3,5,3,3,2,2,4,3,5,3,4,8,2,3,5,3,3,5,3,2,6,2,2,7,4,2,4,4,7,2,3,1,4,2,7,2,2,5
1,9,3,8,2,13,2,3,8,4,5,3,5,3,3,2,3,6,5,12,3,2,3,2,5,3,3,2,3,9,4,3,3,7,6,6,2,1,7,2,2,10,9,2,3,3,7,3,4,6,2,2,2,3,4,2,2,1,4,6,3,5,4,3,3,4,7,1,1,4,2,5,6,5,3,6,2,2,2,6,3,2,3,6,7,3,4,4,7,5,3,3,4,3,3,3,2,4,5,9,6,7,2,3,2,3,3,3,3,8,8,8,5,1,4,2,5,3,5,4,9,2,1,4,2,4,3,7,1,1,1,2,2,2,8,5,6,2,3,5,2,3,6,3,3,1,4,1,2,3,7,4,4,2,10,7,3,2,5,3,9,4,3,2,3,3,2,2,4,5,6,2,3,5,4,2,3,3,5,2,10,5,3,3,5,3,7,3,7,2,2,1,2,6,8,3,4,5,3,5,4,2,6,2,5,1,4,7,3,3, ...

# %%
px.box(data, y = "Quantity", x = "Year", color = "Category")
# Out:
# <div>                            <div id="d6d7feb1-c0ba-4644-88a9-9bc07076b322" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6d7feb1-c0ba-4644-88a9-9bc07076b322")) {                    Plotly.newPlot(                        "d6d7feb1-c0ba-4644-88a9-9bc07076b322",                        [{"alignmentgroup":"True","hovertemplate":"Category=Office Supplies<br>Year=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Office Supplies","marker":{"color":"#636efa"},"name":"Office Supplies","notched":false,"offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"x":[2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2 ...

# %%
data.Profit.describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
px.box(data, y = "Profit")
# Out:
# <div>                            <div id="552103ac-909c-41b9-ac2f-d35de452d992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("552103ac-909c-41b9-ac2f-d35de452d992")) {                    Plotly.newPlot(                        "552103ac-909c-41b9-ac2f-d35de452d992",                        [{"alignmentgroup":"True","hovertemplate":"Profit=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[5.5512,4.2717,-64.7748,-5.487,4.884,1.4796,746.4078,274.491,5.2398,113.6742,204.1092,0.3112,3.0084,9.3312,-53.7096,-18.2525,1.168,9.75,21.2954,1.3583,3.0814,34.3548,2.7072,6.567,-2.5212,238.653,13.0928,5.3392,87.3504,3.9294,25.47,258.696,-53.2856,65.978,10.1493,28.5984,-31.05,-13.6312,6.4864,-23.716,19.6224,36.693,-320.597,4.8609,13.365,9.2928,-51.5154,12.7368,11.58,1.7901,15.9792,224.2674,8.9535,30.0234,4.0542,10.9698,6.6584,5.79,93.5816,181.9818,4.1028,0.0,19.2384,8.34,39.7488,52.6344,4.4712,0.0,9.3312,0.0,30.7818,5.0196,14.3075,12.0252,-16.65,1.3257,6.8982,4.752,3.4196,206.316,-12.224,13.572,5.8045,4.3134,27.248,29.0136,16.0928,6.0368,42.0355,42.0186,7.2,-14.7708,49.6048,9.744,5.5328,2.5984,15.2225,6.8724,4.4344,53.2704,8.2062,24.393,75.3732,103.158,-24.294,4.7724,22.9488,86.3892,6.
# %% [markdown]
# # #8 What Is Confirmatory Data Analysis (CDA)?

# %% [markdown]
# Confirmatory Data Analysis is the part where you evaluate your evidence using traditional statistical tools such as significance, inference, and confidence.
#
#     Assumption 1 - Every summer technology products have the highest sale quantity compared to other product categories.
#     Assumption 2- In New York, there are many big companies, therefore, office supplies product has
#     the highest sale quantity compared to other big states such as Texas, Illinois, and California.

# %% [markdown]
# # `Assumption 1 - Every summer technology products have the highest sale quantity compared to other product categories.`

# %%
seasons = {
    1 : "Winter",
    2 : "Spring",
    3 : "Summer",
    4 : "Fall"
}

# %% [markdown]
# # Creating **Season** column

# %%
data["Season"] = data.Month.astype(int) % 12 // 3 + 1
data.Season = data.Season.map(seasons)
data.sample(20)
# Out:
#      Order Date      Customer Name         State         Category  \
# 6075 2017-12-25       Fred Hopkins    California  Office Supplies
# 1078 2017-09-23          Don Weiss    Washington  Office Supplies
# 7734 2017-09-15       Gene McClure    Washington  Office Supplies
# 1410 2017-11-04         Sam Zeldin         Texas  Office Supplies
# 4839 2017-06-01        Fred Harton          Ohio       Technology
# 1238 2014-08-11      Greg Matthias    Washington        Furniture
# 209  2017-12-01        Joseph Holt      Michigan  Office Supplies
# 8888 2017-12-01         Max Ludwig    California        Furniture
# 8542 2015-12-22        Harold Ryan  Pennsylvania        Furniture
# 7110 2016-04-19       Kunst Miller      New York  Office Supplies
# 3199 2017-12-18      Aaron Hawkins  Pennsylvania  Office Supplies
# 8845 2017-12-18         Beth Paige          Ohio  Office Supplies
# 9411 2016-03-10        Maya Herman       Arizona  Office Supplies
# 213  2015-01-02    Victoria Wilson          Ohio        Furniture
# 1237 2016-10-28    Patrick Gardner       Florida        Furniture
# 4543 2015-07-12          Rob Lucas      Illinois        Furniture
# 8492 2015-10-23      Craig Carroll         Texas  Office Supplies
# 5850 2015-11-10  Philisse Overcash     Minnesota       Technology
# 1439 2017-04-12     Bill Donatelli  Rhode Island  Office Supplies
# 2245 2017-11-21        Barry Franz    California  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 6075      Storage  Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...  270.620
# 1078      Storage               Sterilite Officeware Hinged File Box   31.440
# 7734          Art                       BIC Brite Liner Highlighters   12.420
# 1410       Labels             Alphabetical Labels for Top Tab Filing   23.680
# 4839       Phones  Panasonic KX-TG6844B Expandable Digital Cordle...  158.376
# 1238  Furnishings         Eldon Image Series Desk Accessories, Ebony   12.350
# 209     Fasteners                  Advantus Push Pins, Aluminum Head   52.290
# 8888  Furnishings             Tenex "The Solids" Textured Chair Mats  629.640
# 8542       Chairs              Harbour Creations Steel Folding Chair  422.625
# 7110     Supplies                     Acme Kleen Earth Office Shears    7.760
# 3199          Art       Avery Fluorescent Highlighter Four-Color Set   18.704
# 8845    Fasteners                                       Ideal Clamps    4.824
# 9411      Storage       Mini 13-1/2 Capacity Data Binder Rack, Pearl  104.696
# 213     Bookcases  O'Sullivan 2-Door Barrister Bookcase in Odessa...  452.450
# 1237  Furnishings  Howard Miller 13-1/2" Diameter Rosebrook Wall ...  165.048
# 4543       Chairs         Global Push Button Manager's Chair, Indigo  383.607
# 8492        Paper  TOPS 4 x 6 Fluorescent Color Memo Sheets, 500 ...   60.736
# 5850      Copiers                  Sharp 1540cs Digital Laser Copier  549.990
# 1439      Binders                            Storex Dura Pro Binders   29.700
# 2245   Appliances        Acco Six-Outlet Power Strip, 4' Cord Length    8.620
#
#       Quantity    Profit  Year  Month  Day  Season
# 6075         2    2.7062  2017     12   25  Winter
# 1078         3    8.4888  2017      9   23    Fall
# 7734         3    5.2164  2017      9   15    Fall
# 1410         2    8.8800  2017     11    4    Fall
# 4839         4  -34.3148  2017      6    1  Summer
# 1238         1    5.4340  2014      8   11  Summer
# 209          9   16.2099  2017     12    1  Winter
# 8888         9  107.0388  2017     12    1  Winter
# 8542         7    0.0000  2015     12   22  Winter
# 7110         2    2.2504  2016      4   19  Spring
# 3199         7    2.3380  2017     12   18  Winter
# 8845         3    1.7487  2017     12   18  Winter
# 9411         1    6.5435  2016      3   10  Spring
# 213          5 -244.3230  2015      1    2  Winter
# 1237         3   41.2620  2016     10   28    Fall
# 4543         9   -5.4801  2015      7   12  Summer
# 8492         8   20.4984  2015     10   23    Fall
# 5850         1  274.9950  2015     11   10    Fall
# 1439         5   13.3650  2017      4   12  Spring
# 2245         1    2.2412  2017     11   21    Fall

# %% [markdown]
# # Extracting data related to summer every year

# %%
summer_data = data[data.Season == "Summer"]
summer_data
# Out:
#      Order Date   Customer Name       State         Category Sub-Category  \
# 245  2014-06-01   Dianna Wilson   Minnesota  Office Supplies      Storage
# 307  2014-06-01     Corey Roper  New Jersey  Office Supplies          Art
# 246  2014-06-01   Dianna Wilson   Minnesota  Office Supplies        Paper
# 247  2014-06-01   Dianna Wilson   Minnesota  Office Supplies   Appliances
# 248  2014-06-01   Dianna Wilson   Minnesota  Office Supplies        Paper
# ...         ...             ...         ...              ...          ...
# 1531 2017-08-31    Jeremy Farry     Arizona  Office Supplies      Storage
# 6405 2017-08-31    Bart Watters  Washington        Furniture       Chairs
# 1532 2017-08-31    Jeremy Farry     Arizona  Office Supplies    Fasteners
# 5609 2017-08-31  Barry Gonzalez   Louisiana       Technology  Accessories
# 6406 2017-08-31    Bart Watters  Washington  Office Supplies      Storage
#
#                                            Product Name     Sales  Quantity  \
# 245                        Safco Steel Mobile File Cart   166.720         2
# 307   Boston Heavy-Duty Trimline Electric Pencil Sha...   289.200         6
# 246   Adams Telephone Message Book w/Frequently-Call...    47.880         6
# 247   Honeywell Enviracaire Portable HEPA Air Cleane...  1503.250         5
# 248                                           Xerox 205    25.920         4
# ...                                                 ...       ...       ...
# 1531    Neat Ideas Personal Hanging Folder Files, Black    10.744         1
# 6405  Hon 4700 Series Mobuis Mid-Back Task Chairs wi...   569.568         2
# 1532                   OIC Bulk Pack Metal Binder Clips     8.376         3
# 5609  Plantronics CS510 - Over-the-Head monaural Wir...   659.900         2
# 6406  Sortfiler Multipurpose Personal File Organizer...   149.730         7
#
#         Profit  Year  Month  Day  Season
# 245    41.6800  2014      6    1  Summer
# 307    83.8680  2014      6    1  Summer
# 246    23.9400  2014      6    1  Summer
# 247   496.0725  2014      6    1  Summer
# 248    12.4416  2014      6    1  Summer
# ...        ...   ...    ...  ...     ...
# 1531    0.8058  2017      8   31  Summer
# 6405    7.1196  2017      8   31  Summer
# 1532    2.7222  2017      8   31  Summer
# 5609  217.7670  2017      8   31  Summer
# 6406   43.4217  2017      8   31  Summer
#
# [2133 rows x 13 columns]

# %% [markdown]
# Aggregating data based on Year, Category, and Season columns and summing up the Quantity

# %%
summer_data_agg = summer_data.groupby(["Category","Year","Season"]).agg({"Quantity":"sum"}).reset_index()
summer_data_agg
# Out:
#            Category  Year  Season  Quantity
# 0         Furniture  2014  Summer       343
# 1         Furniture  2015  Summer       386
# 2         Furniture  2016  Summer       402
# 3         Furniture  2017  Summer       486
# 4   Office Supplies  2014  Summer      1031
# 5   Office Supplies  2015  Summer       959
# 6   Office Supplies  2016  Summer      1406
# 7   Office Supplies  2017  Summer      1638
# 8        Technology  2014  Summer       306
# 9        Technology  2015  Summer       296
# 10       Technology  2016  Summer       385
# 11       Technology  2017  Summer       531

# %% [markdown]
# # Let's visualize our result using a grouped bar chart

# %%
px.bar(summer_data_agg,
      x = "Year",
      y = "Quantity",
      color = "Category",
      barmode = "group")
# Out:
# <div>                            <div id="eaf92aaf-0db4-444b-8f87-e8a87eeb7877" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaf92aaf-0db4-444b-8f87-e8a87eeb7877")) {                    Plotly.newPlot(                        "eaf92aaf-0db4-444b-8f87-e8a87eeb7877",                        [{"alignmentgroup":"True","hovertemplate":"Category=Furniture<br>Year=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Furniture","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Furniture","offsetgroup":"Furniture","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[343,386,402,486],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Office Supplies<br>Year=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Office Supplies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Office Supplies","offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[1031,959,1406,1638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Technology<br>Year=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[306,296,385,531],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %% [markdown]
# ## Assumption proved wrong: The graph says that, the quantities of office supplies are higher than the technology

# %% [markdown]
#
# # `Assumption 2- In New York, there are many big companies, therefore, office supplies product has the highest sale quantity compared to other big states such as Texas, Illinois, and California.`

# %% [markdown]
# ## Deriving unique details in the column State to locate the required States to confirm our Assumption

# %%
data["State"].unique()
# Out:
# array(['Texas', 'Illinois', 'Pennsylvania', 'Kentucky', 'Georgia',
#        'California', 'Virginia', 'Delaware', 'Louisiana', 'Ohio',
#        'South Carolina', 'Oregon', 'Arizona', 'Michigan', 'Tennessee',
#        'Arkansas', 'Florida', 'Indiana', 'Nevada', 'South Dakota',
#        'New York', 'Wisconsin', 'Washington', 'New Jersey', 'Missouri',
#        'North Carolina', 'Colorado', 'Utah', 'Mississippi', 'Minnesota',
#        'Iowa', 'New Mexico', 'Massachusetts', 'Alabama', 'Montana',
#        'Idaho', 'Maryland', 'Connecticut', 'New Hampshire', 'Oklahoma',
#        'Nebraska', 'Maine', 'Kansas', 'Rhode Island',
#        'District of Columbia', 'Vermont', 'Wyoming', 'North Dakota',
#        'West Virginia'], dtype=object)

# %%
state_supply = data.loc[data['State'].isin(["New York", "Texas", "Illinois", "California"])]

# %%
max_supplies = state_supply.groupby(["State","Category"]).agg({"Quantity":"sum"}).reset_index()
max_supplies
# Out:
#          State         Category  Quantity
# 0   California        Furniture      1696
# 1   California  Office Supplies      4566
# 2   California       Technology      1405
# 3     Illinois        Furniture       448
# 4     Illinois  Office Supplies      1095
# 5     Illinois       Technology       302
# 6     New York        Furniture       877
# 7     New York  Office Supplies      2585
# 8     New York       Technology       762
# 9        Texas        Furniture       766
# 10       Texas  Office Supplies      2299
# 11       Texas       Technology       659

# %% [markdown]
# # Let's Visualize the data frame

# %%
px.bar(max_supplies,
      x = "State",
      y = "Quantity",
      color = "Category",
      barmode = "group")
# Out:
# <div>                            <div id="007572db-460b-4a47-af32-9ff143752b6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("007572db-460b-4a47-af32-9ff143752b6b")) {                    Plotly.newPlot(                        "007572db-460b-4a47-af32-9ff143752b6b",                        [{"alignmentgroup":"True","hovertemplate":"Category=Furniture<br>State=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Furniture","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Furniture","offsetgroup":"Furniture","orientation":"v","showlegend":true,"textposition":"auto","x":["California","Illinois","New York","Texas"],"xaxis":"x","y":[1696,448,877,766],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Office Supplies<br>State=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Office Supplies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Office Supplies","offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"textposition":"auto","x":["California","Illinois","New York","Texas"],"xaxis":"x","y":[4566,1095,2585,2299],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Technology<br>State=%{x}<br>Quantity=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"textposition":"auto","x":["California","Illinois","New York","Texas"],"xaxis":"x","y":[1405,302,762,659],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %% [markdown]
# ## Assumption proved correct: The graph says that, the quantities of office supplies are relatively higher in NY than the other cities.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "kjswnth/the-notebook" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/kjswnth/the-notebook
# 'https://jovian.ai/kjswnth/the-notebook'
